# %% [markdown]
# import pandas as pd
# import os
# import json

# %% [markdown]
# # Issues

# %%
df1 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_Airflow_Issues.json', orient='records', lines=True)
df2 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_celery_Issues.json', orient='records', lines=True)


df3 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_dask_Issues.json', orient='records', lines=True)
df4 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_drake_Issues.json', orient='records', lines=True)

df5 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_galaxy_Issues.json', orient='records', lines=True)
df6 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_knime_Issues.json', orient='records', lines=True)


df7 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_luigi_Issues.json', orient='records', lines=True)
df8 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_nextflow_Issues.json', orient='records', lines=True)

df9 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_snakemake_Issues.json', orient='records', lines=True)

df10 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_nifi_Issues.json', orient='records', lines=True)
df11 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_oozie_Issues.json', orient='records', lines=True)

# %%
merged_issues_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], ignore_index=True)
merged_issues_df
# Out:
#                id                                              title  \
# 0      2428317348  Inconsistent dataintervalstartdataintervalend ...
# 1      2428215155                    Setting language textarea field
# 2      2427966039                Add option hide Datasets Graph View
# 3      2427473325      GKEStartPodOperator Error pod agent available
# 4      2427028176  Airflow Backend Database RDS PostgreSQL high C...
# ...           ...                                                ...
# 50455      308435  buildsetupsetupmavensh us bashisms reference b...
# 50456      260087  Oozie console reference RowExpanderjs file inc...
# 50457      255786  XTestCasegetTestUser method return hardcoded u...
# 50458      250646  binmkdistrosh DskipTests dmysql uroot llocalho...
# 50459      250640                        reference SVN binmkdistrosh
#
#                                                     body          created_at  \
# ...

# %% [markdown]
# # Pull Requests

# %%
df1 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_Airflow_PullRequests.json', orient='records', lines=True)
df2 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_celery_PullRequests.json', orient='records', lines=True)


df3 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_dask_PullRequests.json', orient='records', lines=True)
df4 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_drake_PullRequests.json', orient='records', lines=True)

df5 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_galaxy_PullRequests.json', orient='records', lines=True)
df6 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_knime_PullRequests.json', orient='records', lines=True)


df7 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_luigi_PullRequests.json', orient='records', lines=True)
df8 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_nextflow_PullRequests.json', orient='records', lines=True)

df9 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_snakemake_PullRequests.json', orient='records', lines=True)

df10 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_nifi_PullRequests.json', orient='records', lines=True)
df11 = pd.read_json('../../Replication Package/Data/GitHub Issues and Pull Requests/Preprocessed_oozie_PullRequests.json', orient='records', lines=True)

# %%
merged_pull_requests_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], ignore_index=True)
merged_pull_requests_df
# df_state = merged_pull_requests_df['state'].unique()
# df_state
# Out:
#                 id                                              title  \
# 0       1986285972          Add missing internalapi method found test
# 1       1986264602                feat add dagstats rest api endpoint
# 2       1986184586         Speed SBOM generation using newest feature
# 3       1986099077  Fix failing test dagprocessortestjobrunner db ...
# 4       1986038413                   Add dataset event info dag graph
# ...            ...                                                ...
# 101292    11739258                                      Antlr version
# 101293    11623984                                       Apache trunk
# 101294     5026843                                  Fb yahoo trunk gd
# 101295     3672576                          Fixed javadoc getJobsInfo
# 101296     1818562  documentation Minor spelling formatting fix RE...
#
#                                                      body          created_at  \
# ...

# %%
merged_issues_df['title'] = merged_issues_df['title'].fillna('')
merged_issues_df['body'] = merged_issues_df['body'].fillna('')

merged_pull_requests_df['title'] = merged_pull_requests_df['title'].fillna('')
merged_pull_requests_df['body'] = merged_pull_requests_df['body'].fillna('')

# %%
nan_rows = merged_issues_df[merged_issues_df['title'].isna()]
nan_rows
# Out:
# Empty DataFrame
# Columns: [id, title, body, created_at, closed_at, state]
# Index: []

# %%
nan_rows = merged_pull_requests_df[merged_pull_requests_df['body'].isna()]
nan_rows
# Out:
# Empty DataFrame
# Columns: [id, title, body, created_at, closed_at, state]
# Index: []

# %%
merged_issues_df['Text'] = merged_issues_df['title']+ ' '+ merged_issues_df['body']
merged_pull_requests_df['Text'] = merged_pull_requests_df['title']+ ' '+ merged_pull_requests_df['body']

# %%
preprocessed_df_issues = merged_issues_df[merged_issues_df['created_at']<'2024-02-01']
preprocessed_df_issues['Text'] = preprocessed_df_issues['Text'].apply(str)
# preprocessed_df_issues
# Out:
# /tmp/ipykernel_2248328/360146655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_df_issues['Text'] = preprocessed_df_issues['Text'].apply(str)

# %%
preprocessed_df_pull_requests = merged_pull_requests_df[merged_pull_requests_df['created_at']<'2024-02-01']
preprocessed_df_pull_requests['Text'] = preprocessed_df_pull_requests['Text'].apply(str)
#preprocessed_df_pull_requests
# Out:
# /tmp/ipykernel_2248328/3649041764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_df_pull_requests['Text'] = preprocessed_df_pull_requests['Text'].apply(str)

# %%
preprocessed_df_issues['TextLen'] = preprocessed_df_issues['Text'].str.len()
# preprocessed_df = preprocessed_df.sort_values(by='TextLen')
preprocessed_df_issues = preprocessed_df_issues[preprocessed_df_issues['TextLen'] >4]
# Out:
# /tmp/ipykernel_2248328/1083829177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_df_issues['TextLen'] = preprocessed_df_issues['Text'].str.len()

# %%
preprocessed_df_pull_requests['TextLen'] = preprocessed_df_pull_requests['Text'].str.len()
# preprocessed_df_pull_requests = preprocessed_df_pull_requests.sort_values(by='TextLen')
preprocessed_df_pull_requests = preprocessed_df_pull_requests[preprocessed_df_pull_requests['TextLen']>4]
# Out:
# /tmp/ipykernel_2248328/788418194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_df_pull_requests['TextLen'] = preprocessed_df_pull_requests['Text'].str.len()

# %%
len(preprocessed_df_issues)
preprocessed_df_issues

# %%
# len(preprocessed_df_pull_requests)
# preprocessed_df_pull_requests

# %%
preprocessed_df_issues.to_csv('FinalIssues.csv')
preprocessed_df_pull_requests.to_csv('FinalPullRequests.csv')

# %%
preprocessed_df = pd.concat([preprocessed_df_issues, preprocessed_df_pull_requests], ignore_index=True)
preprocessed_df
# Out:
#                 id                                              title  \
# 0       2110557588             Allow Dag Processor Manager log stdout
# 1       2110393836  Aws BatchSensor maxretries change deferrable f...
# 2       2110329891           Sequential Execution Dynamic Mapped Task
# 3       2108957289  Support defining Kubernetes resource without K...
# 4       2108828904                        search list dag task idname
# ...            ...                                                ...
# 140395    11739258                                      Antlr version
# 140396    11623984                                       Apache trunk
# 140397     5026843                                  Fb yahoo trunk gd
# 140398     3672576                          Fixed javadoc getJobsInfo
# 140399     1818562  documentation Minor spelling formatting fix RE...
#
#                                                      body          created_at  \
# ...

# %%
preprocessed_df.reset_index(drop=True, inplace=True)

# %%
preprocessed_df
# Out:
#                 id                                              title  \
# 0       2110557588             Allow Dag Processor Manager log stdout
# 1       2110393836  Aws BatchSensor maxretries change deferrable f...
# 2       2110329891           Sequential Execution Dynamic Mapped Task
# 3       2108957289  Support defining Kubernetes resource without K...
# 4       2108828904                        search list dag task idname
# ...            ...                                                ...
# 140395    11739258                                      Antlr version
# 140396    11623984                                       Apache trunk
# 140397     5026843                                  Fb yahoo trunk gd
# 140398     3672576                          Fixed javadoc getJobsInfo
# 140399     1818562  documentation Minor spelling formatting fix RE...
#
#                                                      body          created_at  \
# ...

# %% [markdown]
# # Pre-calculate Embeddings

# %%
from sentence_transformers import SentenceTransformer

## Precalculate Embedding
embedding_model = SentenceTransformer("multi-qa-MiniLM-L6-dot-v1")
# Out:
# You try to use a model that was created with version 3.0.0.dev0, however, your version is 2.7.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
#
#
#
# /home/kha060/anaconda3/envs/BTI/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/kha060/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:107: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
print(preprocessed_df.columns)
# Out:
# Index(['id', 'title', 'body', 'created_at', 'closed_at', 'state', 'Text',
#        'TextLen'],
#       dtype='object')

# %%
preprocessed_df.columns = preprocessed_df.columns.str.strip()

# %%
preprocessed_df['Text'] = preprocessed_df['Text'].str.strip()

# Replace multiple spaces between words with a single space
preprocessed_df['Text'] = preprocessed_df['Text'].str.replace(r'\s+', ' ', regex=True)

# %%
# Try encoding
try:
    embeddings_Text = embedding_model.encode(preprocessed_df['Text'], show_progress_bar=True)
except KeyError as e:
    print(f"KeyError encountered: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Batches:   0%|          | 0/4388 [00:00<?, ?it/s]

# %%
from umap import UMAP
umap_model = UMAP(n_neighbors=10, n_components=5, min_dist=0.1, metric='euclidean')

from hdbscan import HDBSCAN
hdbscan_model = HDBSCAN(min_cluster_size=100, min_samples = 120, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 2))

# %%
from bertopic import BERTopic
topic_model = BERTopic(
    embedding_model = embedding_model,
    umap_model = umap_model,
    hdbscan_model = hdbscan_model,
    vectorizer_model = vectorizer_model,
    nr_topics = 13,
    top_n_words = 20,
    verbose = True
)

# %%
## Topics Generation
topics, probs = topic_model.fit_transform(preprocessed_df['Text'], embeddings_Text)
topic_model.get_topic_info()
# Out:
# 2024-07-29 18:53:23,742 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...

# %%
topic_model.get_topic_info().to_csv('../../Replication Package/Data/Output/topics_info-QA-Model_GitHub_Issues_PullRequests.csv')

# %% [markdown]
# # Document Distribution

# %%
document_distribution = topic_model.get_document_info(preprocessed_df['Text'])
document_distribution
# Out:
#                                                  Document  Topic  \
# 0       Allow Dag Processor Manager log stdout Descrip...     -1
# 1       Aws BatchSensor maxretries change deferrable f...     -1
# 2       Sequential Execution Dynamic Mapped Task Descr...     -1
# 3       Support defining Kubernetes resource without K...      0
# 4       search list dag task idname Description curren...     -1
# ...                                                   ...    ...
# 140395                                      Antlr version     -1
# 140396                                       Apache trunk     -1
# 140397                                  Fb yahoo trunk gd      0
# 140398          Fixed javadoc getJobsInfo Defaults result     -1
# 140399  documentation Minor spelling formatting fix RE...     -1
#
#                               Name  \
# 0          -1_case_change_add_file
# 1          -1_case_change_add_file
# 2          -1_case_change_add_file
# 3       0_case_change_airflow_test
# ...

# %%
concatenated_df = pd.concat([preprocessed_df, document_distribution], axis=1)
concatenated_df
# Out:
#                 id                                              title  \
# 0       2110557588             Allow Dag Processor Manager log stdout
# 1       2110393836  Aws BatchSensor maxretries change deferrable f...
# 2       2110329891           Sequential Execution Dynamic Mapped Task
# 3       2108957289  Support defining Kubernetes resource without K...
# 4       2108828904                        search list dag task idname
# ...            ...                                                ...
# 140395    11739258                                      Antlr version
# 140396    11623984                                       Apache trunk
# 140397     5026843                                  Fb yahoo trunk gd
# 140398     3672576                          Fixed javadoc getJobsInfo
# 140399     1818562  documentation Minor spelling formatting fix RE...
#
#                                                      body          created_at  \
# ...

# %%
distinct_topics = concatenated_df['Topic'].unique()
distinct_topics
# Out:
# array([-1,  0,  5,  2, 11,  4,  1,  6,  7,  9,  8,  3, 10])

# %%
for topic in distinct_topics:
    df_topic = concatenated_df[concatenated_df['Topic'] == topic]
    filename = f"{topic}_Topics_data.csv"
    df_topic.to_csv('../../Replication Package/Data/Output/Topic Distribution GitHub/' + filename)
